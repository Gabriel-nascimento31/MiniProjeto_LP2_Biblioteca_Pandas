# %%
import pandas as pd

dados = {
    'Data': ['2026-01-10', '2026-01-11', '2026-01-12', '2026-01-12', '2026-01-13', '2026-01-14'],
    'Produto': ['Notebook', 'Smartphone', 'Notebook', 'Teclado', 'Smartphone', 'Teclado'],
    'Regiao': ['Sudeste', 'Nordeste', 'Sudeste', 'Sul', 'Norte', 'Sudeste'],
    'Quantidade': [2, 5, 1, 10, 3, 8],
    'Preco_Unitario': [4500, 2000, 4500, 150, 2000, 150]
}

df = pd.DataFrame(dados)
print("--- Dados Brutos Carregados ---")
display(df)
# Out:
# --- Dados Brutos Carregados ---
#          Data     Produto    Regiao  Quantidade  Preco_Unitario
# 0  2026-01-10    Notebook   Sudeste           2            4500
# 1  2026-01-11  Smartphone  Nordeste           5            2000
# 2  2026-01-12    Notebook   Sudeste           1            4500
# 3  2026-01-12     Teclado       Sul          10             150
# 4  2026-01-13  Smartphone     Norte           3            2000
# 5  2026-01-14     Teclado   Sudeste           8             150

# %%
df['Data'] = pd.to_datetime(df['Data'])

df['Faturamento'] = df['Quantidade'] * df['Preco_Unitario']

print("\n--- DataFrame Atualizado com Faturamento ---")
display(df[['Data', 'Produto', 'Quantidade', 'Faturamento']])
# Out:
# --- DataFrame Atualizado com Faturamento ---
#         Data     Produto  Quantidade  Faturamento
# 0 2026-01-10    Notebook           2         9000
# 1 2026-01-11  Smartphone           5        10000
# 2 2026-01-12    Notebook           1         4500
# 3 2026-01-12     Teclado          10         1500
# 4 2026-01-13  Smartphone           3         6000
# 5 2026-01-14     Teclado           8         1200

# %%
faturamento_total = df['Faturamento'].sum()
print(f"Faturamento Total: R$ {faturamento_total:,.2f}")
# Out:
# Faturamento Total: R$ 32,200.00

# %%
faturamento_por_produto = df.groupby('Produto')['Faturamento'].sum().sort_values(ascending=False)
print("\nFaturamento por Produto:")
display(faturamento_por_produto)
# Out:
# Faturamento por Produto:
# Produto
# Smartphone    16000
# Notebook      13500
# Teclado        2700
# Name: Faturamento, dtype: int64

# %%
faturamento_por_regiao = df.groupby('Regiao')['Faturamento'].sum().sort_values(ascending=False)
print("\nFaturamento por Região:")
display(faturamento_por_regiao)
# Out:
# Faturamento por Região:
# Regiao
# Sudeste     14700
# Nordeste    10000
# Norte        6000
# Sul          1500
# Name: Faturamento, dtype: int64

# %%
ticket_medio = df['Faturamento'].mean()
print(f"Ticket Médio por Venda: R$ {ticket_medio:,.2f}")
# Out:
# Ticket Médio por Venda: R$ 5,366.67

# %%
faturamento_por_produto.plot(kind='bar', color='skyblue', edgecolor='black')
# Out:
# <Axes: xlabel='Produto'>
